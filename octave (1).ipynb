# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # IMPORTING AND READING THE INDIVIDUAL MONTHLY DATASET FOR FIST HALF OF 2019

# %%
jan=pd.read_csv(r"C:\Users\User\Desktop\january.csv")
jan.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE  \
# 0  2019        1      1             6            7  06-01-19
# 1  2019        1      1             7            1  07-01-19
# 2  2019        1      1             8            2  08-01-19
# 3  2019        1      1             9            3  09-01-19
# 4  2019        1      1            10            4  10-01-19
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                9E                  20363         9E   N8694A  ...
# 1                9E                  20363         9E   N8970D  ...
# 2                9E                  20363         9E   N820AY  ...
# 3                9E                  20363         9E   N840AY  ...
# 4                9E                  20363         9E   N8969A  ...
#
#    ARR_TIME_BLK  CANCELLED  CANCELLATION_CODE  DIVERTED CRS_ELAPSED_TIME  \
# 0     1700-1759          0                NaN         0             47.0
# ...

# %%
feb=pd.read_csv(r"C:\Users\User\Desktop\febuary.csv")
feb.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE  \
# 0  2019        1      2             4            1  04-02-19
# 1  2019        1      2             5            2  05-02-19
# 2  2019        1      2             6            3  06-02-19
# 3  2019        1      2             7            4  07-02-19
# 4  2019        1      2             8            5  08-02-19
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                AA                  19805         AA   N989AN  ...
# 1                AA                  19805         AA   N346PR  ...
# 2                AA                  19805         AA   N872NN  ...
# 3                AA                  19805         AA   N316PF  ...
# 4                AA                  19805         AA   N855NN  ...
#
#    ARR_TIME_BLK  CANCELLED  CANCELLATION_CODE  DIVERTED CRS_ELAPSED_TIME  \
# 0     1600-1659          0                NaN         0              314
# ...

# %%
march=pd.read_csv(r"C:\Users\User\Desktop\march.csv")
march.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE  \
# 0  2019        1      3            21            4  21-03-19
# 1  2019        1      3            22            5  22-03-19
# 2  2019        1      3            23            6  23-03-19
# 3  2019        1      3            17            7  17-03-19
# 4  2019        1      3            18            1  18-03-19
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                9E                  20363         9E   N8943A  ...
# 1                9E                  20363         9E   N8688C  ...
# 2                9E                  20363         9E   N840AY  ...
# 3                9E                  20363         9E   N279PQ  ...
# 4                9E                  20363         9E   N906XJ  ...
#
#    ARR_TIME_BLK  CANCELLED  CANCELLATION_CODE  DIVERTED CRS_ELAPSED_TIME  \
# 0     1800-1859          0                NaN         0              104
# ...

# %%
april=pd.read_csv(r"C:\Users\User\Desktop\april.csv")
april.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE  \
# 0  2019        2      4             5            5  05-04-19
# 1  2019        2      4             6            6  06-04-19
# 2  2019        2      4             7            7  07-04-19
# 3  2019        2      4             8            1  08-04-19
# 4  2019        2      4             9            2  09-04-19
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                NK                  20416         NK   N646NK  ...
# 1                NK                  20416         NK   N615NK  ...
# 2                NK                  20416         NK   N633NK  ...
# 3                NK                  20416         NK   N655NK  ...
# 4                NK                  20416         NK   N605NK  ...
#
#    ARR_TIME_BLK  CANCELLED  CANCELLATION_CODE  DIVERTED CRS_ELAPSED_TIME  \
# 0     2300-2359          0                NaN         0              188
# ...

# %%
may=pd.read_csv(r"C:\Users\User\Desktop\164848536_T_ONTIME_REPORTING.csv")
may.drop(columns='Unnamed: 56',axis=1,inplace=True)
may.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2019        2      5            28            2  2019-05-28
# 1  2019        2      5            28            2  2019-05-28
# 2  2019        2      5            28            2  2019-05-28
# 3  2019        2      5            28            2  2019-05-28
# 4  2019        2      5            28            2  2019-05-28
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                YX                  20452         YX   N732YX  ...
# 1                YX                  20452         YX   N652RW  ...
# 2                YX                  20452         YX   N862RW  ...
# 3                YX                  20452         YX   N862RW  ...
# 4                YX                  20452         YX   N732YX  ...
#
#    ARR_TIME_BLK  CANCELLED  CANCELLATION_CODE  DIVERTED CRS_ELAPSED_TIME  \
# 0     0900-0959        0.0                NaN       0.0            151.0
# ...

# %%
june=pd.read_csv(r"C:\Users\User\Desktop\june.csv")
june.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE  \
# 0  2019        2      6             1            6  01-06-19
# 1  2019        2      6             1            6  01-06-19
# 2  2019        2      6             1            6  01-06-19
# 3  2019        2      6             1            6  01-06-19
# 4  2019        2      6             1            6  01-06-19
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                B6                  20409         B6   N929JB  ...
# 1                B6                  20409         B6   N981JT  ...
# 2                B6                  20409         B6   N969JT  ...
# 3                B6                  20409         B6   N339JB  ...
# 4                B6                  20409         B6   N997JL  ...
#
#    ARR_TIME_BLK  CANCELLED  CANCELLATION_CODE  DIVERTED CRS_ELAPSED_TIME  \
# 0     2300-2359          0                NaN         0              335
# ...

# %% [markdown]
# # SECTION ONE-DATA MINING ANSWERS

# %% [markdown]
# -The airline that had most number of travels between January - March 2019

# %%
data=pd.concat([jan,feb,march],axis=0)
data.describe()
# Out:
#             YEAR    QUARTER         MONTH  DAY_OF_MONTH   DAY_OF_WEEK  \
# count  1749234.0  1749234.0  1.749234e+06  1.749234e+06  1.749234e+06
# mean      2019.0        1.0  2.027491e+00  1.562263e+01  3.965747e+00
# std          0.0        0.0  8.333305e-01  8.698703e+00  1.974492e+00
# min       2019.0        1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2019.0        1.0  1.000000e+00  8.000000e+00  2.000000e+00
# 50%       2019.0        1.0  2.000000e+00  1.600000e+01  4.000000e+00
# 75%       2019.0        1.0  3.000000e+00  2.300000e+01  6.000000e+00
# max       2019.0        1.0  3.000000e+00  3.100000e+01  7.000000e+00
#
#        OP_CARRIER_AIRLINE_ID  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# count           1.749234e+06       1.749234e+06       1.749234e+06
# mean            1.998393e+04       2.538028e+03       1.265829e+04
# std             3.767028e+02       1.811783e+03       1.520706e+03
# ...

# %%
pd.pivot_table(data,values='FLIGHTS',columns=['ORIGIN'],aggfunc=np.sum).transpose().sort_values(by='FLIGHTS',ascending=False)
# Out:
#         FLIGHTS
# ORIGIN
# ATL       93418
# ORD       77734
# DFW       68664
# CLT       56310
# DEN       55523
# ...         ...
# PPG          27
# OWB          27
# ADK          26
# OGD          25
# PAE           4
#
# [347 rows x 1 columns]

# %% [markdown]
# ATLANTA HAS THE HIGHEST NUMBER OG FLIGHT JANUARY TO MARCH 2019

# %% [markdown]
# -The total number of flights between January 2019 and June 2019 (first half of 2019)

# %%
full_data=pd.concat([jan,feb,march,april,may,june],axis=0)
full_data.describe()
# Out:
#             YEAR       QUARTER         MONTH  DAY_OF_MONTH   DAY_OF_WEEK  \
# count  3634338.0  3.634338e+06  3.634338e+06  3.634338e+06  3.634338e+06
# mean      2019.0  1.518693e+00  3.576097e+00  1.565555e+01  3.949786e+00
# std          0.0  4.996505e-01  1.703839e+00  8.722514e+00  1.982340e+00
# min       2019.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2019.0  1.000000e+00  2.000000e+00  8.000000e+00  2.000000e+00
# 50%       2019.0  2.000000e+00  4.000000e+00  1.600000e+01  4.000000e+00
# 75%       2019.0  2.000000e+00  5.000000e+00  2.300000e+01  6.000000e+00
# max       2019.0  2.000000e+00  6.000000e+00  3.100000e+01  7.000000e+00
#
#        OP_CARRIER_AIRLINE_ID  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# count           3.634338e+06       3.634338e+06       3.634338e+06
# mean            1.998447e+04       2.541868e+03       1.265197e+04
# std             3.756723e+02       1.810177e+03       1.522622e+03
# ...

# %%
full_data.to_csv(r"C:\Users\User\Desktop\data.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-787cbf7463da> in <module>
# ----> 1 full_data.to_csv(r"C:\Users\User\Desktop\data.csv", index = False)
#
# NameError: name 'full_data' is not defined

# %%
full_data.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM',
#        'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID',
#        'ORIGIN_CITY_MARKET_ID', 'ORIGIN', 'ORIGIN_CITY_NAME',
#        'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_NM',
#        'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
#        'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR',
#        'DEST_STATE_FIPS', 'DEST_STATE_NM', 'DEST_WAC', 'CRS_DEP_TIME',
#        'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP', 'ARR_TIME_BLK',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
# ...

# %%
full_data["TAXI_DEL"]=full_data["DEP_DELAY_NEW"] + full_data["TAXI_OUT"]

# %%
Origin2=pd.pivot_table(full_data,values=['TAXI_DEL'],columns=['ORIGIN'], aggfunc=np.sum).transpose().sort_values(by='TAXI_DEL',ascending=False)
print(Origin2)
# Out:
#          TAXI_DEL
# ORIGIN
# ORD     6559846.0
# ATL     5526245.0
# DFW     5131601.0
# DEN     4031080.0
# CLT     3894987.0
# ...           ...
# ADK        1024.0
# HYA         685.0
# GST         458.0
# DLG         347.0
# AKN         233.0
#
# [358 rows x 1 columns]

# %%
full_data['FLIGHTS'].sum() #total number of flights in first half of 2019
# Out:
# 3634338.0

# %% [markdown]
#                     THE TOTAL AIR TIME BY ALL AIRLINES IN MAY 2019(IN HOURS)

# %%
(may['AIR_TIME'].sum())//60
# Out:
# 1154951.0

# %% [markdown]
#                                 THE BUSIEST CITY IN APRIL 2019

# %%
pd.pivot_table(april,values='FLIGHTS',columns=['ORIGIN_CITY_NAME'],aggfunc=np.sum).transpose().sort_values(by='FLIGHTS',ascending=False)
# Out:
#                        FLIGHTS
# ORIGIN_CITY_NAME
# Chicago, IL              34396
# Atlanta, GA              32940
# New York, NY             25094
# Dallas/Fort Worth, TX    23933
# Houston, TX              19936
# ...                        ...
# Pago Pago, TT                9
# Branson, MO                  8
# Adak Island, AK              8
# Hayden, CO                   2
# Gunnison, CO                 1
#
# [344 rows x 1 columns]

# %% [markdown]
# Chicago,Illinois was the busiest city in april with total number of 34396 flights

# %% [markdown]
#                           AIRLINE THAT COVERED THE MOST DISTANCE IN JUNE 2019

# %%
pd.pivot_table(june,values='DISTANCE',columns=['ORIGIN'],aggfunc=np.sum).transpose().sort_values(by='DISTANCE',ascending=False)
# Out:
#         DISTANCE
# ORIGIN
# LAX     25157579
# ATL     22303330
# ORD     21960585
# DFW     21246821
# DEN     20361396
# ...          ...
# PSG         4620
# OGD         4352
# HYA         3528
# WRG         3390
# GST         1025
#
# [356 rows x 1 columns]

# %% [markdown]
# Los Angeles (LAX) covered the most distance of 25157579

# %% [markdown]
#              *****The Tail Number of the aircraft that covered the most distance in Q2 of 2019*****

# %%
dataQ2=pd.concat([april,may,june],axis=0)
dataQ2.describe()
# Out:
#             YEAR    QUARTER         MONTH  DAY_OF_MONTH   DAY_OF_WEEK  \
# count  1885104.0  1885104.0  1.885104e+06  1.885104e+06  1.885104e+06
# mean      2019.0        2.0  5.013086e+00  1.568610e+01  3.934975e+00
# std          0.0        0.0  8.137815e-01  8.744443e+00  1.989481e+00
# min       2019.0        2.0  4.000000e+00  1.000000e+00  1.000000e+00
# 25%       2019.0        2.0  4.000000e+00  8.000000e+00  2.000000e+00
# 50%       2019.0        2.0  5.000000e+00  1.600000e+01  4.000000e+00
# 75%       2019.0        2.0  6.000000e+00  2.300000e+01  6.000000e+00
# max       2019.0        2.0  6.000000e+00  3.100000e+01  7.000000e+00
#
#        OP_CARRIER_AIRLINE_ID  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# count           1.885104e+06       1.885104e+06       1.885104e+06
# mean            1.998496e+04       2.545431e+03       1.264610e+04
# std             3.747128e+02       1.808679e+03       1.524375e+03
# ...

# %%
pd.pivot_table(dataQ2,values='DISTANCE',columns=['TAIL_NUM'],aggfunc=np.sum).transpose().sort_values(by='DISTANCE',ascending=False)
# Out:
#           DISTANCE
# TAIL_NUM
# N934JB    598286.0
# N943JT    592006.0
# N984JB    588931.0
# N982JB    585632.0
# N979JT    583407.0
# ...            ...
# N861NW       528.0
# N271AY       449.0
# N270AY       449.0
# N802AE       225.0
# N684RW       224.0
#
# [5558 rows x 1 columns]

# %% [markdown]
# N934JB was the aircraft(tail number) that covered the most distance in Q2(April to June) of 2019 with the distance of 598286

# %% [markdown]
#                The state that recorded the most delays in the 2nd Quarter of 2019

# %%
pd.pivot_table(dataQ2,values='DEP_DELAY_NEW',columns=['ORIGIN_STATE_NM'],aggfunc=np.sum).transpose().sort_values(by='DEP_DELAY_NEW',ascending=False)
# Out:
#                                                 DEP_DELAY_NEW
# ORIGIN_STATE_NM
# Texas                                               3790603.0
# Florida                                             2615154.0
# California                                          2602832.0
# Illinois                                            2050217.0
# New York                                            1791874.0
# Georgia                                             1533982.0
# North Carolina                                      1473544.0
# Colorado                                            1253558.0
# Virginia                                            1113001.0
# New Jersey                                           847320.0
# Pennsylvania                                         740736.0
# Arizona                                              710825.0
# Michigan                                             690174.0
# Massachusetts                                        678891.0
# ...

# %% [markdown]
# Texas had the most delays in quarter 2 of 2019

# %% [markdown]
#                 The daily average Taxi-out time in New York state in February 2019

# %%
NY=feb[feb['ORIGIN_STATE_NM']=='New York']
NY['TAXI_OUT'].mean()
# Out:
# 24.689726862140656

# %% [markdown]
#                 How many airlines with New York destinations were diverted in Q1 2019

# %%
#DATASETS ON DIVERTED DESTINAIONS FOR JAN,FEB, and MARCH
data1=pd.read_csv(r"C:\Users\User\Desktop\data1.csv")
data2=pd.read_csv(r"C:\Users\User\Desktop\data2.csv")
data3=pd.read_csv(r"C:\Users\User\Desktop\data3.csv")
Q1=pd.concat([data1,data2,data3],axis=0)
Q1.head()
# Out:
#   DEST                  DEST_CITY_NAME DEST_STATE_NM  DIV_AIRPORT_LANDINGS  \
# 0  ABE  Allentown/Bethlehem/Easton, PA  Pennsylvania                     0
# 1  ABE  Allentown/Bethlehem/Easton, PA  Pennsylvania                     0
# 2  ABE  Allentown/Bethlehem/Easton, PA  Pennsylvania                     0
# 3  ABE  Allentown/Bethlehem/Easton, PA  Pennsylvania                     0
# 4  ABE  Allentown/Bethlehem/Easton, PA  Pennsylvania                     0
#
#    Unnamed: 4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
NYK=Q1[Q1['DEST_STATE_NM']=='New York']
NYK['DIV_AIRPORT_LANDINGS'].sum()
# Out:
# 446

# %% [markdown]
# ### DATA ANALYSIS FOR MODELING AND PREDICTING TAXI OUT TIME FROM JANUARY TO JUNE 2019

# %% [markdown]
# ### Data cleaning

# %%
full_data.head() #READING OF FULL DATA
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE  \
# 0  2019        1      1             6            7  06-01-19
# 1  2019        1      1             7            1  07-01-19
# 2  2019        1      1             8            2  08-01-19
# 3  2019        1      1             9            3  09-01-19
# 4  2019        1      1            10            4  10-01-19
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                9E                  20363         9E   N8694A  ...
# 1                9E                  20363         9E   N8970D  ...
# 2                9E                  20363         9E   N820AY  ...
# 3                9E                  20363         9E   N840AY  ...
# 4                9E                  20363         9E   N8969A  ...
#
#    CANCELLED  CANCELLATION_CODE  DIVERTED  CRS_ELAPSED_TIME  \
# 0        0.0                NaN       0.0              47.0
# 1        0.0                NaN       0.0              47.0
# ...

# %%
full_data.shape #TO KNOW THE NUMBER OF ROWS AND COLUMNS
# Out:
# (3634338, 57)

# %%
#DROPPING OF COLUMNS THAT ARE NOT RELEVANT OR RELATED TO THE TARGET VARIABLE
del_columns=["AIR_TIME","ACTUAL_ELAPSED_TIME","CANCELLATION_CODE","ARR_DELAY_GROUP","ARR_DEL15","ARR_DELAY_NEW","DEST_AIRPORT_SEQ_ID","DEST_AIRPORT_ID","DEP_TIME","DEP_TIME_BLK",
        "ARR_DELAY","ARR_TIME","WHEELS_ON","DEP_DELAY_GROUP","CRS_ELAPSED_TIME","DIVERTED","CANCELLED","DEST_CITY_MARKET_ID","DEP_DEL15","DEP_DELAY","DEP_DELAY_NEW",
        "ARR_TIME_BLK","CRS_ARR_TIME","TAXI_IN","DEST_WAC","DEST_STATE_NM","DEST_STATE_FIPS","DEST_STATE_ABR","DEST_CITY_NAME","WHEELS_OFF","YEAR","FLIGHTS"]
full_data.drop(columns=del_columns, axis=1, inplace=True)
full_data.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK   FL_DATE OP_UNIQUE_CARRIER  \
# 0        1      1             6            7  06-01-19                9E
# 1        1      1             7            1  07-01-19                9E
# 2        1      1             8            2  08-01-19                9E
# 3        1      1             9            3  09-01-19                9E
# 4        1      1            10            4  10-01-19                9E
#
#    OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ...  \
# 0                  20363         9E   N8694A               3280  ...
# 1                  20363         9E   N8970D               3280  ...
# 2                  20363         9E   N820AY               3280  ...
# 3                  20363         9E   N840AY               3280  ...
# 4                  20363         9E   N8969A               3280  ...
#
#    ORIGIN_STATE_ABR  ORIGIN_STATE_FIPS  ORIGIN_STATE_NM ORIGIN_WAC DEST  \
# ...

# %%
full_data.dtypes #TO VIEW THE DATATYE OF EACH OF THE COLUMNS
# Out:
# QUARTER                    int64
# MONTH                      int64
# DAY_OF_MONTH               int64
# DAY_OF_WEEK                int64
# FL_DATE                   object
# OP_UNIQUE_CARRIER         object
# OP_CARRIER_AIRLINE_ID      int64
# OP_CARRIER                object
# TAIL_NUM                  object
# OP_CARRIER_FL_NUM          int64
# ORIGIN_AIRPORT_ID          int64
# ORIGIN_AIRPORT_SEQ_ID      int64
# ORIGIN_CITY_MARKET_ID      int64
# ORIGIN                    object
# ORIGIN_CITY_NAME          object
# ORIGIN_STATE_ABR          object
# ORIGIN_STATE_FIPS          int64
# ORIGIN_STATE_NM           object
# ORIGIN_WAC                 int64
# DEST                      object
# CRS_DEP_TIME               int64
# TAXI_OUT                 float64
# DISTANCE                 float64
# DISTANCE_GROUP             int64
# TAXI_DEL                 float64
# dtype: object

# %%
full_data.isnull().sum() #TO VIEW THE TOTAL NUMBER OF MISSING VALUES OF EACH COLUMN
# Out:
# QUARTER                      0
# MONTH                        0
# DAY_OF_MONTH                 0
# DAY_OF_WEEK                  0
# FL_DATE                      0
# OP_UNIQUE_CARRIER            0
# OP_CARRIER_AIRLINE_ID        0
# OP_CARRIER                   0
# TAIL_NUM                 12641
# OP_CARRIER_FL_NUM            0
# ORIGIN_AIRPORT_ID            0
# ORIGIN_AIRPORT_SEQ_ID        0
# ORIGIN_CITY_MARKET_ID        0
# ORIGIN                       0
# ORIGIN_CITY_NAME             0
# ORIGIN_STATE_ABR             0
# ORIGIN_STATE_FIPS            0
# ORIGIN_STATE_NM              0
# ORIGIN_WAC                   0
# DEST                         0
# CRS_DEP_TIME                 0
# TAXI_OUT                 84726
# DISTANCE                     0
# DISTANCE_GROUP               0
# TAXI_DEL                 84727
# dtype: int64

# %%
#DROPPING MISSING VALUES BY ROWS
New_data=full_data.dropna(how="any",axis=0,inplace=False)
New_data.isnull().sum()
# Out:
# QUARTER                  0
# MONTH                    0
# DAY_OF_MONTH             0
# DAY_OF_WEEK              0
# FL_DATE                  0
# OP_UNIQUE_CARRIER        0
# OP_CARRIER_AIRLINE_ID    0
# OP_CARRIER               0
# TAIL_NUM                 0
# OP_CARRIER_FL_NUM        0
# ORIGIN_AIRPORT_ID        0
# ORIGIN_AIRPORT_SEQ_ID    0
# ORIGIN_CITY_MARKET_ID    0
# ORIGIN                   0
# ORIGIN_CITY_NAME         0
# ORIGIN_STATE_ABR         0
# ORIGIN_STATE_FIPS        0
# ORIGIN_STATE_NM          0
# ORIGIN_WAC               0
# DEST                     0
# CRS_DEP_TIME             0
# TAXI_OUT                 0
# DISTANCE                 0
# DISTANCE_GROUP           0
# TAXI_DEL                 0
# dtype: int64

# %%
New_data.shape #THE SIZE OF ROWS AND COLUMNS REMAINING
# Out:
# (3549611, 25)

# %%
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3549611 entries, 0 to 636690
# Data columns (total 25 columns):
# QUARTER                  int64
# MONTH                    int64
# DAY_OF_MONTH             int64
# DAY_OF_WEEK              int64
# FL_DATE                  object
# OP_UNIQUE_CARRIER        object
# OP_CARRIER_AIRLINE_ID    int64
# OP_CARRIER               object
# TAIL_NUM                 object
# OP_CARRIER_FL_NUM        int64
# ORIGIN_AIRPORT_ID        int64
# ORIGIN_AIRPORT_SEQ_ID    int64
# ORIGIN_CITY_MARKET_ID    int64
# ORIGIN                   object
# ORIGIN_CITY_NAME         object
# ORIGIN_STATE_ABR         object
# ORIGIN_STATE_FIPS        int64
# ORIGIN_STATE_NM          object
# ORIGIN_WAC               int64
# DEST                     object
# CRS_DEP_TIME             int64
# TAXI_OUT                 float64
# DISTANCE                 float64
# DISTANCE_GROUP           int64
# TAXI_DEL                 float64
# ...

# %%
delcolumns=['FL_DATE','ORIGIN_STATE_ABR','ORIGIN_STATE_ABR']
New_data.drop(columns=delcolumns, axis=1, inplace=True)
New_data.head()
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0        1      1             6            7                9E
# 1        1      1             7            1                9E
# 2        1      1             8            2                9E
# 3        1      1             9            3                9E
# 4        1      1            10            4                9E
#
#    OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  \
# 0                  20363         9E   N8694A               3280
# 1                  20363         9E   N8970D               3280
# ...

# %%
print(New_data['OP_UNIQUE_CARRIER'].unique())
# Out:
# ['9E' 'WN' 'OO' 'AA' 'MQ' 'G4' 'OH' 'B6' 'AS' 'DL' 'YV' 'EV' 'F9' 'YX'
#  'UA' 'HA' 'NK']

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.pivot_table(New_data,values='TAXI_OUT',columns=['ORIGIN'],aggfunc=np.mean).transpose().sort_values(by='TAXI_OUT',ascending=False)
# Out:
#          TAXI_OUT
# ORIGIN
# ISN     27.887701
# LGA     27.622965
# JFK     26.715397
# EWR     24.306305
# MMH     24.000000
# ...           ...
# ADQ      7.492063
# BRW      7.202857
# OGD      7.120000
# SMX      6.910112
# OWB      6.000000
#
# [358 rows x 1 columns]

# %%
pd.pivot_table(New_data,values='TAXI_OUT',columns=['TAIL_NUM'],aggfunc=np.mean).transpose().sort_values(by='TAXI_OUT',ascending=False)
# Out:
#            TAXI_OUT
# TAIL_NUM
# ALL       43.000000
# N1610D    40.500000
# N782UA    37.294118
# N27015    32.421053
# N77014    30.222222
# ...             ...
# N475HA    10.753296
# N477HA    10.726106
# N495HA    10.698001
# N489HA    10.693484
# N480HA    10.544865
#
# [5747 rows x 1 columns]

# %%
pd.pivot_table(New_data,values='TAXI_OUT',columns=['CRS_DEP_TIME'],aggfunc=np.mean).transpose().sort_values(by='TAXI_OUT',ascending=False)
# Out:
#                TAXI_OUT
# CRS_DEP_TIME
# 106           52.500000
# 1929          23.725065
# 859           23.009382
# 1829          22.716142
# 809           22.476447
# ...                 ...
# 301            9.000000
# 227            9.000000
# 241            8.666667
# 229            8.333333
# 453            8.000000
#
# [1336 rows x 1 columns]

# %%
#ENCODE TAIL NUMBER AND ORIGIN FROM OBJECT TO NUMERICAL
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
New_data['ORIGIN']=enc.fit_transform(New_data['ORIGIN'])
New_data['TAIL_NUM']=enc.fit_transform(New_data['TAIL_NUM'])
New_data['DEST']=enc.fit_transform(New_data['DEST'])
New_data['OP_CARRIER']=enc.fit_transform(New_data['OP_CARRIER'])
New_data['OP_UNIQUE_CARRIER']=enc.fit_transform(New_data['OP_UNIQUE_CARRIER'])
New_data['ORIGIN_CITY_NAME']=enc.fit_transform(New_data['ORIGIN_CITY_NAME'])
New_data['ORIGIN_STATE_NM']=enc.fit_transform(New_data['ORIGIN_STATE_NM'])
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# ...

# %%
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3549611 entries, 0 to 636690
# Data columns (total 23 columns):
# QUARTER                  int64
# MONTH                    int64
# DAY_OF_MONTH             int64
# DAY_OF_WEEK              int64
# OP_UNIQUE_CARRIER        int32
# OP_CARRIER_AIRLINE_ID    int64
# OP_CARRIER               int32
# TAIL_NUM                 int32
# OP_CARRIER_FL_NUM        int64
# ORIGIN_AIRPORT_ID        int64
# ORIGIN_AIRPORT_SEQ_ID    int64
# ORIGIN_CITY_MARKET_ID    int64
# ORIGIN                   int32
# ORIGIN_CITY_NAME         int32
# ORIGIN_STATE_FIPS        int64
# ORIGIN_STATE_NM          int32
# ORIGIN_WAC               int64
# DEST                     int32
# CRS_DEP_TIME             int64
# TAXI_OUT                 float64
# DISTANCE                 float64
# DISTANCE_GROUP           int64
# TAXI_DEL                 float64
# dtypes: float64(3), int32(7), int64(13)
# memory usage: 555.2 MB

# %%
New_data.isnull().sum()
# Out:
# QUARTER                  0
# MONTH                    0
# DAY_OF_MONTH             0
# DAY_OF_WEEK              0
# OP_UNIQUE_CARRIER        0
# OP_CARRIER_AIRLINE_ID    0
# OP_CARRIER               0
# TAIL_NUM                 0
# OP_CARRIER_FL_NUM        0
# ORIGIN_AIRPORT_ID        0
# ORIGIN_AIRPORT_SEQ_ID    0
# ORIGIN_CITY_MARKET_ID    0
# ORIGIN                   0
# ORIGIN_CITY_NAME         0
# ORIGIN_STATE_FIPS        0
# ORIGIN_STATE_NM          0
# ORIGIN_WAC               0
# DEST                     0
# CRS_DEP_TIME             0
# TAXI_OUT                 0
# DISTANCE                 0
# DISTANCE_GROUP           0
# TAXI_DEL                 0
# dtype: int64

# %%
New_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### DATA VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt
month_grouped = New_data.groupby(['MONTH'])['TAXI_OUT'].mean()

month_grouped = month_grouped.reset_index()

ax = sns.barplot(x='MONTH', y='TAXI_OUT', data=month_grouped, color='#45B39D');

ax.set_title('Taxi-Out time by Month');
ax.set_ylabel('Average Taxi-Out time (Minutes)');

# %% [markdown]
# ### 1-jan,2-feb,3-mar,4-apr,5-may and 6-jun
# This shows that january and febuary has the highest average taxi-out time

# %%
weekday_grouped = New_data.groupby(['DAY_OF_WEEK'])['TAXI_OUT'].mean()

weekday_grouped = weekday_grouped.reset_index()

ax = sns.barplot(x='DAY_OF_WEEK', y='TAXI_OUT', data=weekday_grouped , color='#45B39D');

ax.set_title('Taxi-Out time by Days of the week');
ax.set_ylabel('Average Taxi-Out time (Minutes)');

# %% [markdown]
# ### 1-mon,2-tues,3-wed,4-thur,5-fri,6-sat and 7-sun
# This shows that the lowest average taxi-out time is on saturdays

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(New_data.corr(), annot=True, cmap="RdBu")
plt.figure(figsize=(50, 50))
plt.show()

# %%
correlations = New_data.corr()['TAXI_OUT'].sort_values()
print(correlations)
# Out:
# OP_CARRIER              -0.085467
# OP_UNIQUE_CARRIER       -0.085467
# ORIGIN_WAC              -0.073493
# ORIGIN_CITY_MARKET_ID   -0.048481
# QUARTER                 -0.038346
# MONTH                   -0.037498
# TAIL_NUM                -0.024438
# ORIGIN_AIRPORT_ID       -0.012451
# ORIGIN_AIRPORT_SEQ_ID   -0.012450
# DAY_OF_WEEK             -0.008847
# CRS_DEP_TIME            -0.007966
# ORIGIN                  -0.007170
# DAY_OF_MONTH            -0.002577
# ORIGIN_CITY_NAME         0.003273
# DEST                     0.015094
# DISTANCE_GROUP           0.034310
# DISTANCE                 0.035624
# ORIGIN_STATE_FIPS        0.057008
# ORIGIN_STATE_NM          0.059494
# OP_CARRIER_FL_NUM        0.093938
# OP_CARRIER_AIRLINE_ID    0.204430
# TAXI_DEL                 0.265830
# TAXI_OUT                 1.000000
# Name: TAXI_OUT, dtype: float64

# %% [markdown]
# ## MODEL EVALUATION

# %%
New_data['TAXI_OUT'].hist()

# %% [markdown]
# Taxi out time does not follow normal distribution,hence normalization or standardization

# %%
#creating dependent and independent variables
x=New_data.loc[:,(['CRS_DEP_TIME', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'DEST', 'DISTANCE',
       'DISTANCE_GROUP', 'MONTH', 'OP_CARRIER', 'OP_CARRIER_AIRLINE_ID',
       'OP_CARRIER_FL_NUM', 'OP_UNIQUE_CARRIER', 'ORIGIN', 'ORIGIN_AIRPORT_ID',
       'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN_CITY_NAME',
       'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_NM', 'ORIGIN_WAC', 'QUARTER',
       'TAIL_NUM', 'TAXI_OUT'])].values
y=New_data.loc[:,'TAXI_OUT'].values

# %%
New_data.columns
# Out:
# Index(['QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER',
#        'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID',
#        'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_NM',
#        'ORIGIN_WAC', 'DEST', 'CRS_DEP_TIME', 'TAXI_OUT', 'DISTANCE',
#        'DISTANCE_GROUP', 'TAXI_DEL'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler #normalizing of the independent variable
scaler=MinMaxScaler()
x=scaler.fit_transform(x)
print(x)
# Out:
# [[0.69720102 0.16666667 1.         ... 0.         0.79463975 0.07079646]
#  [0.69720102 0.2        0.         ... 0.         0.83014271 0.03982301]
#  [0.69720102 0.23333333 0.16666667 ... 0.         0.69648451 0.07522124]
#  ...
#  [0.427905   0.63333333 0.5        ... 1.         0.83901845 0.09734513]
#  [0.427905   0.66666667 0.66666667 ... 1.         0.9698921  0.05752212]
#  [0.427905   0.7        0.83333333 ... 1.         0.31691612 0.06637168]]

# %% [markdown]
# # Train-Test split

# %%
from sklearn.model_selection import  train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((2839688, 22), (709923, 22), (2839688,), (709923,))

# %%
from sklearn.linear_model import LinearRegression,BayesianRidge,HuberRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score,r2_score,mean_absolute_error,mean_squared_error,mean_squared_log_error

# %%
linReg=LinearRegression()
linReg.fit(x_train,y_train)
y_pred=linReg.predict(x_test)
print('The r-squared is',r2_score(y_test,y_pred))
print('The mean absolute error is',mean_absolute_error(y_test,y_pred))
print('The mean squared error is',mean_squared_error(y_test,y_pred))
# Out:
# The r-squared is 1.0
# The mean absolute error is 4.4576519192691546e-11
# The mean squared error is 1.9870843269057807e-21

# %%
bayesian=BayesianRidge()
bayesian.fit(x_train,y_train)
y_pred1=bayesian.predict(x_test)
print('The r-squared is',r2_score(y_test,y_pred1))
print('The mean absolute error is',mean_absolute_error(y_test,y_pred1))
print('The mean squared error is',mean_squared_error(y_test,y_pred1))
# Out:
# The r-squared is -8.295721838741605e+22
# The mean absolute error is 2707599224566.2837
# The mean squared error is 8.550891178989054e+24

# %% [markdown]
# Linear Regresion model is the best model,hence should be used to predict  predicts the taxi-out time for an aircraft 2 hours before the scheduled departure time
